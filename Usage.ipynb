# %% [markdown]
# # Intro
#
# In this notebook, I will demonstrate the usage of a **custom built** neural network framework for **multi and binary class** classification tasks as well as for regession.
# For image classification we will use the popular "*fashion_mnist_images*" dataset, which contains grayscale images of fashion items
# belonging to **10** different classes. The goal is to train a neural network to **classify** these images accurately.

# %% [markdown]
# # Install required libraries
# Since the entire framework has been built from **scratch**, only basic libraries are required for its usage.

# %%
# !pip install numpy
# !pip install opencv-python
# !pip install matplotlib
# !pip install urllib
# !pip install zipfile

# %% [markdown]
# # Dataset preparation
# The following cell is responsible for downloading and extracting the fashion_mnist_images dataset,
# which will be used for classification tasks. The dataset contains images of various fashion items.
#
# In the dataset folder there are folders names from **0** to **9**, each representing a class.
#
# ![alternatvie text](https://balintdaniel.com/public/notebooks/folders.png)
#
# - For binary classification use the other provided fownload link or simply dete calsses 2-9.
# - **For regression please provide you own dataset that you wish to use. Or implement RegressionDataset class**
#
# > NOTE: You are not obligated to use images; any other data can be
# > utilized. In the case of other datasets, you need to implement the
# > corresponding version of the ClassificationDataset class.

# %%
import os
import urllib.request
from zipfile import ZipFile

# Multi class dataset
URL = 'https://balintdaniel.com/cloud/index.php/s/ZTMfTmKyj7y5XTJ/download?path=%2Fdatasets&files=classification_dataset.zip'
FILE = 'classification_dataset.zip'

# Binary dataset
#URL = 'https://balintdaniel.com/cloud/index.php/s/ZTMfTmKyj7y5XTJ/download?path=%2Fdatasets&files=binary_classification_dataset.zip'
#FILE = 'binary_classification_dataset.zip'

# Check if the dataset file already exists in the current directory
if not os.path.isfile(FILE):
    # If the file does not exist, download it from the URL and save it as FILE
    print(f'Downloading {URL} and saving as {FILE}...')
    urllib.request.urlretrieve(URL, FILE)

# Unzip the downloaded dataset file
print('Unzipping images...')
with ZipFile(FILE) as zip_images:
    zip_images.extractall("./")
print('Done!')
# Out:
# Unzipping images...
# Done!

# %% [markdown]
# The cell below demonstrates the loading, augmentation, balancing, preprocessing, shuffling,
# normalization, reshaping, and splitting of the image classification dataset.
# **The order of the dataset function calls are important!**

# %%
from lib.dataset import ImageClassificationDataset

# Create an instance of the ImageClassificationDataset class
dataset = ImageClassificationDataset()

# Load the classification dataset with the specified parameters
dataset.load(
    "classification_dataset", # Multi class dataset folder name
    #"binary_classification_dataset", # Binary dataset folder name
    size=28, # Size of the images
    binary=False, # Is binary classification?
)

# Augment the dataset with additional image transformations
dataset.augment(
    # TODO
)

# Balance the dataset by adjusting the class distribution
dataset.balance(
    # TODO
)

# Preprocess the dataset by applying preprocessing techniques
dataset.preprocess(
    auto_white_balance_and_contrast=True
)

# Shuffle the dataset to randomize the order of the samples
dataset.shuffle()

# Normalize the dataset to bring the pixel values into a consistent range. (-1 1)
dataset.normalize()

# Reshape the dataset for the network to accept
dataset.reshape()

# Split the dataset into training, validation, and test sets
X_train, y_train, X_valid, y_valid, X_test, y_test = dataset.split(valid=0.2, test=0.1) # 0.2 = 20%
# Out:
# Train batch contains 49_402 images
# Validation batch contains 14_115 images
# Test batch contains 7_057 images

# %%
# Preview of the traing images
dataset.visualize_dataset_preview()

# %% [markdown]
# The goal of the t-SNE algorithm is to project high-dimensional data onto a lower-dimensional space while preserving the
# similarities between the data points. The method positions similar data points as close neighbors in the output space,
# while representing distant data points as distant points. Thus, t-SNE helps to reveal the structure and relationships within the data.

# %%
dataset.visualize_dataset()

# %% [markdown]
# # Build a model
# This example is a model with **fully connected layers.**
# > Feel free to experiment with different layers and their parameters to achieve better results.

# %%
from lib.model import *
from lib.layers import *
from lib.metrics import *
from lib.optimizers import *
from lib.activations import *


# Create an instance of the Model class
model = Model()

# Add layers to the model
model.add(Layer_Dense(X_train.shape[1], 64))  # INPUT LAYER. Dense layer with input shape and 64 neurons
model.add(Activation_ReLU())  # ReLU activation function
model.add(Layer_Dense(64, 64, weight_regularizer_l2=5e-4, bias_regularizer_l2=7e-5))  # Dense layer with regularization
model.add(Activation_ReLU())  # ReLU activation function
model.add(Layer_Dropout(0.2))  # Dropout layer with a dropout rate of 0.2
model.add(Layer_Dense(64, 64))  # Dense layer with 64 neurons
model.add(Activation_ReLU())  # ReLU activation function
model.add(Layer_Dropout(0.2))  # Dropout layer with a dropout rate of 0.2
model.add(Layer_Dense(64, len(dataset.labels)))  # OUTPUT LAYER. Dense layer with the number of output neurons
# model.add(Layer_Dense(64, 1))  # OUTPUT LAYER. For binary classification and regression
model.add(Activation_Softmax())  # Softmax activation function. For multi class
# model.add(Activation_Sigmoid()) # Sigmoind activation for binary classification
# model.add(Activation_Linear()) # Linear activation for regression

# Set the loss function, optimizer, and accuracy metric for the model
model.set(
    loss=Loss_CategoricalCrossentropy(), # Multi class
    # loss=Loss_BinaryCrossentropy(), # Binary
    # loss=Loss_MeanSquaredError(), # Regression
    optimizer=Optimizer_Adam(learning_rate=0.001, decay=0.001),
    accuracy=Accuracy_Categorical(binary=False) # Is binary?
    # accuracy=Accuracy_Regression() For regression
)

# Finalize the model architecture
model.finalize()

# %% [markdown]
# # Model training

# %%
model.train(
    X_train,
    y_train, 
    validation_data=(X_valid, y_valid), # Or None
    epochs=100, 
    batch_size=128,
    early_stop=5 # When the loss value does not decrease further for X epochs, it stops the training process.
)
# Out:
# Epoch(1/100), Training:   accuracy: 0.613, loss: 0.997, learning rate: 0.000722021660650, data loss: 0.993, regularization loss: 0.004004
# Validation: accuracy: 0.754, loss: 0.677
#
# Epoch(2/100), Training:   accuracy: 0.752, loss: 0.678, learning rate: 0.000564652738566, data loss: 0.673, regularization loss: 0.006006
# Validation: accuracy: 0.781, loss: 0.599
#
# Epoch(3/100), Training:   accuracy: 0.784, loss: 0.603, learning rate: 0.000463606861382, data loss: 0.596, regularization loss: 0.007007
# Validation: accuracy: 0.805, loss: 0.543
#
# Epoch(4/100), Training:   accuracy: 0.805, loss: 0.553, learning rate: 0.000393236335037, data loss: 0.546, regularization loss: 0.007007
# Validation: accuracy: 0.817, loss: 0.505
#
# Epoch(5/100), Training:   accuracy: 0.820, loss: 0.517, learning rate: 0.000341413451690, data loss: 0.509, regularization loss: 0.008008
# Validation: accuracy: 0.822, loss: 0.487
#
# Epoch(6/100), Training:   accuracy: 0.828, loss: 0.494, learning rate: 0.000301659125189, data loss: 0.485, regularization loss: 0.008008
# Validation: accuracy: 0.826, loss: 0.471
#
# Epoch(7/100), Training:   accuracy: 0.834, loss: 0.475, learning rate: 0.000270197243988, data loss: 0.467, regularization loss: 0.008008
# Validation: accuracy: 0.831, loss: 0.459
#
# Epoch(8/100), Training:   accuracy: 0.840, loss: 0.460, learning rate: 0.000244678248104, data loss: 0.451, regularization loss: 0.009009
# Validation: accuracy: 0.836, loss: 0.445
#
# Epoch(9/100), Training:   accuracy: 0.844, loss: 0.449, learning rate: 0.000223563603845, data loss: 0.441, regularization loss: 0.009009
# Validation: accuracy: 0.842, loss: 0.432
#
# Epoch(10/100), Training:   accuracy: 0.850, loss: 0.436, learning rate: 0.000205803663305, data loss: 0.427, regularization loss: 0.009009
# Validation: accuracy: 0.847, loss: 0.426
#
# Epoch(11/100), Training:   accuracy: 0.852, loss: 0.428, learning rate: 0.000190657769304, data loss: 0.418, regularization loss: 0.009009
# Validation: accuracy: 0.846, loss: 0.426
#
# Epoch(12/100), Training:   accuracy: 0.854, loss: 0.421, learning rate: 0.000177588350204, data loss: 0.412, regularization loss: 0.009009
# Validation: accuracy: 0.851, loss: 0.416
#
# Epoch(13/100), Training:   accuracy: 0.858, loss: 0.415, learning rate: 0.000166195778627, data loss: 0.405, regularization loss: 0.009009
# Validation: accuracy: 0.851, loss: 0.413
#
# Epoch(14/100), Training:   accuracy: 0.862, loss: 0.407, learning rate: 0.000156176792129, data loss: 0.397, regularization loss: 0.009009
# Validation: accuracy: 0.851, loss: 0.416
#
# Epoch(15/100), Training:   accuracy: 0.862, loss: 0.402, learning rate: 0.000147297098247, data loss: 0.392, regularization loss: 0.010010
# Validation: accuracy: 0.853, loss: 0.411
#
# Epoch(16/100), Training:   accuracy: 0.864, loss: 0.394, learning rate: 0.000139372822300, data loss: 0.385, regularization loss: 0.010010
# Validation: accuracy: 0.855, loss: 0.406
#
# Epoch(17/100), Training:   accuracy: 0.865, loss: 0.390, learning rate: 0.000132257637879, data loss: 0.380, regularization loss: 0.010010
# Validation: accuracy: 0.856, loss: 0.404
#
# Epoch(18/100), Training:   accuracy: 0.868, loss: 0.386, learning rate: 0.000125833647917, data loss: 0.376, regularization loss: 0.010010
# Validation: accuracy: 0.857, loss: 0.402
#
# Epoch(19/100), Training:   accuracy: 0.869, loss: 0.381, learning rate: 0.000120004800192, data loss: 0.371, regularization loss: 0.010010
# Validation: accuracy: 0.857, loss: 0.402
#
# Epoch(20/100), Training:   accuracy: 0.871, loss: 0.378, learning rate: 0.000114692051841, data loss: 0.368, regularization loss: 0.010010
# Validation: accuracy: 0.858, loss: 0.398
#
# Epoch(21/100), Training:   accuracy: 0.872, loss: 0.375, learning rate: 0.000109829763866, data loss: 0.365, regularization loss: 0.010010
# Validation: accuracy: 0.858, loss: 0.398
#
# Epoch(22/100), Training:   accuracy: 0.874, loss: 0.371, learning rate: 0.000105362975450, data loss: 0.361, regularization loss: 0.010010
# Validation: accuracy: 0.859, loss: 0.395
#
# Epoch(23/100), Training:   accuracy: 0.875, loss: 0.365, learning rate: 0.000101245317404, data loss: 0.355, regularization loss: 0.010010
# Validation: accuracy: 0.859, loss: 0.394
#
# Epoch(24/100), Training:   accuracy: 0.876, loss: 0.364, learning rate: 0.000097437396473, data loss: 0.354, regularization loss: 0.010010
# Validation: accuracy: 0.861, loss: 0.391
#
# Epoch(25/100), Training:   accuracy: 0.877, loss: 0.361, learning rate: 0.000093905531036, data loss: 0.351, regularization loss: 0.010010
# Validation: accuracy: 0.861, loss: 0.391
#
# Epoch(26/100), Training:   accuracy: 0.879, loss: 0.359, learning rate: 0.000090620752152, data loss: 0.349, regularization loss: 0.010010
# Validation: accuracy: 0.861, loss: 0.389
#
# Epoch(27/100), Training:   accuracy: 0.879, loss: 0.357, learning rate: 0.000087558007180, data loss: 0.347, regularization loss: 0.010010
# Validation: accuracy: 0.862, loss: 0.387
#
# Epoch(28/100), Training:   accuracy: 0.879, loss: 0.353, learning rate: 0.000084695519607, data loss: 0.343, regularization loss: 0.010010
# Validation: accuracy: 0.861, loss: 0.387
#
# Epoch(29/100), Training:   accuracy: 0.881, loss: 0.351, learning rate: 0.000082014270483, data loss: 0.341, regularization loss: 0.010010
# Validation: accuracy: 0.861, loss: 0.387
#
# Epoch(30/100), Training:   accuracy: 0.882, loss: 0.348, learning rate: 0.000079497575324, data loss: 0.337, regularization loss: 0.010010
# Validation: accuracy: 0.861, loss: 0.387
#
# Epoch(31/100), Training:   accuracy: 0.882, loss: 0.347, learning rate: 0.000077130736599, data loss: 0.337, regularization loss: 0.010010
# Validation: accuracy: 0.862, loss: 0.383
#
# Epoch(32/100), Training:   accuracy: 0.883, loss: 0.344, learning rate: 0.000074900756498, data loss: 0.334, regularization loss: 0.010010
# Validation: accuracy: 0.861, loss: 0.384
#
# Epoch(33/100), Training:   accuracy: 0.885, loss: 0.343, learning rate: 0.000072796098129, data loss: 0.333, regularization loss: 0.010010
# Validation: accuracy: 0.862, loss: 0.384
#
# Epoch(34/100), Training:   accuracy: 0.884, loss: 0.342, learning rate: 0.000070806485874, data loss: 0.332, regularization loss: 0.010010
# Validation: accuracy: 0.863, loss: 0.383
#
# Epoch(35/100), Training:   accuracy: 0.886, loss: 0.337, learning rate: 0.000068922737611, data loss: 0.327, regularization loss: 0.010010
# Validation: accuracy: 0.862, loss: 0.382
#
# Epoch(36/100), Training:   accuracy: 0.885, loss: 0.339, learning rate: 0.000067136623028, data loss: 0.329, regularization loss: 0.010010
# Validation: accuracy: 0.862, loss: 0.381
#
# Epoch(37/100), Training:   accuracy: 0.885, loss: 0.336, learning rate: 0.000065440743407, data loss: 0.326, regularization loss: 0.010010
# Validation: accuracy: 0.863, loss: 0.382
#
# Epoch(38/100), Training:   accuracy: 0.887, loss: 0.334, learning rate: 0.000063828429182, data loss: 0.323, regularization loss: 0.010010
# Validation: accuracy: 0.863, loss: 0.382
#
# Epoch(39/100), Training:   accuracy: 0.887, loss: 0.333, learning rate: 0.000062293652277, data loss: 0.323, regularization loss: 0.010010
# Validation: accuracy: 0.863, loss: 0.381
#
# Epoch(40/100), Training:   accuracy: 0.888, loss: 0.331, learning rate: 0.000060830950788, data loss: 0.321, regularization loss: 0.010010
# Validation: accuracy: 0.863, loss: 0.381
#
# Epoch(41/100), Training:   accuracy: 0.888, loss: 0.332, learning rate: 0.000059435364042, data loss: 0.322, regularization loss: 0.010010
# Validation: accuracy: 0.864, loss: 0.379
#
# Epoch(42/100), Training:   accuracy: 0.888, loss: 0.330, learning rate: 0.000058102376387, data loss: 0.320, regularization loss: 0.010010
# Validation: accuracy: 0.865, loss: 0.380
#
# Epoch(43/100), Training:   accuracy: 0.888, loss: 0.328, learning rate: 0.000056827868387, data loss: 0.318, regularization loss: 0.010010
# Validation: accuracy: 0.865, loss: 0.381
#
# Epoch(44/100), Training:   accuracy: 0.888, loss: 0.329, learning rate: 0.000055608074292, data loss: 0.318, regularization loss: 0.010010
# Validation: accuracy: 0.865, loss: 0.379
#
# Epoch(45/100), Training:   accuracy: 0.891, loss: 0.326, learning rate: 0.000054439544885, data loss: 0.316, regularization loss: 0.010010
# Validation: accuracy: 0.866, loss: 0.378
#
# Epoch(46/100), Training:   accuracy: 0.891, loss: 0.325, learning rate: 0.000053319114903, data loss: 0.315, regularization loss: 0.010010
# Validation: accuracy: 0.866, loss: 0.378
#
# Epoch(47/100), Training:   accuracy: 0.890, loss: 0.324, learning rate: 0.000052243874406, data loss: 0.314, regularization loss: 0.010010
# Validation: accuracy: 0.866, loss: 0.379
#
# Epoch(48/100), Training:   accuracy: 0.890, loss: 0.322, learning rate: 0.000051211143545, data loss: 0.311, regularization loss: 0.010010
# Validation: accuracy: 0.866, loss: 0.378
#
# Epoch(49/100), Training:   accuracy: 0.890, loss: 0.321, learning rate: 0.000050218450259, data loss: 0.311, regularization loss: 0.010010
# Validation: accuracy: 0.865, loss: 0.378
#
# Epoch(50/100), Training:   accuracy: 0.893, loss: 0.320, learning rate: 0.000049263510518, data loss: 0.310, regularization loss: 0.010010
# Validation: accuracy: 0.865, loss: 0.378
#
# Epoch(51/100), Training:   accuracy: 0.892, loss: 0.318, learning rate: 0.000048344210781, data loss: 0.308, regularization loss: 0.010010
# Validation: accuracy: 0.866, loss: 0.378
#
# Epoch(52/100), Training:   accuracy: 0.893, loss: 0.318, learning rate: 0.000047458592378, data loss: 0.308, regularization loss: 0.010010
# Validation: accuracy: 0.867, loss: 0.377
#
# Epoch(53/100), Training:   accuracy: 0.893, loss: 0.316, learning rate: 0.000046604837582, data loss: 0.305, regularization loss: 0.010010
# Validation: accuracy: 0.866, loss: 0.377
#
# Epoch(54/100), Training:   accuracy: 0.894, loss: 0.317, learning rate: 0.000045781257153, data loss: 0.307, regularization loss: 0.010010
# Validation: accuracy: 0.867, loss: 0.377
#
# Epoch(55/100), Training:   accuracy: 0.894, loss: 0.313, learning rate: 0.000044986279185, data loss: 0.303, regularization loss: 0.010010
# Validation: accuracy: 0.867, loss: 0.378
#
# Epoch(56/100), Training:   accuracy: 0.894, loss: 0.313, learning rate: 0.000044218439089, data loss: 0.303, regularization loss: 0.010010
# Validation: accuracy: 0.868, loss: 0.378
#
# Epoch(57/100), Training:   accuracy: 0.894, loss: 0.312, learning rate: 0.000043476370593, data loss: 0.302, regularization loss: 0.010010
# Validation: accuracy: 0.867, loss: 0.378
#
# Epoch(58/100), Training:   accuracy: 0.894, loss: 0.313, learning rate: 0.000042758797623, data loss: 0.302, regularization loss: 0.010010
# Validation: accuracy: 0.867, loss: 0.378
#
# Training stopped due to lack of improvement in loss under 5 epochs.

# %%
# Visualize the history of the training process
model.visualize_train()

# %%
# Test the model performance using the test dataset batch
model.evaluate(X_test, y_test)
# Out:
# Validation: accuracy: 0.872, loss: 0.367
# (0.8723253507156016, 0.3671058889049107)

# %% [markdown]
# # Save model
# You can save the entire model with the architecture of all layers and their weights, or you can save only the weights and other parameters. Saving only the parameters can be useful in **transfer learning** scenarios or for implementing other visualization tasks.

# %%
# Save only parameters
model.save_parameters("params.p")

# %%
# Save the whole model and weights too
model.save("model.m")

# %% [markdown]
# # Load model
# Just as you can save the model using the mentioned methods, you can also load them back.

# %%
# You can load weights to an existing model
model.load_parameters("params.p")

# %%
# Or you can load a pretrained model with weights
model = Model.load("model.m")

# %% [markdown]
# # Predictions

# %%
import random
import matplotlib.pyplot as plt


fashion_mnist_labels = {   
    0: 'T-shirt/top',
    1: 'Trouser',
    2: 'Pullover',
    3: 'Dress',
    4: 'Coat',
    5: 'Sandal',
    6: 'Shirt',
    7: 'Sneaker',
    8: 'Bag',
    9: 'Ankle boot'
}

img = random.randint(0, len(X_test)-1)  # Random image from test batch

plt.imshow((X_test[img].reshape(28, 28)), cmap='gray')  # Display the image
plt.show()

# Multi class prediction
confidences = model.predict(X_test[img])  # Get the prediction confidence for the image
predictions = model.output_layer_activation.predictions(confidences)  # Convert confidence to predicted class label

prediction = fashion_mnist_labels[predictions[0]]  # Get the predicted label
true_label = fashion_mnist_labels[y_test[img]]  # Get the true label from the test dataset

print(f"Prediction: {prediction}, True: {true_label}, Confidence: {round(max(confidences[0])*100, 2)}%")  # Print the prediction and true label

# Binary prediction
# confidences = model.predict(X_test[img])[0] # Pass image(s) in array
# prediction = 0 if confidences[0] < 0.5 else 1 # Confidence to prediction 
# print(f"Prediction: {fashion_mnist_labels[prediction]}, True: {fashion_mnist_labels[y_test[img][0]]}") # Prediction with labels
# Out:
# Prediction: Pullover, True: Pullover, Confidence: 77.1%
